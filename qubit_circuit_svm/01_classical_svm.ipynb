# %% [markdown]
# # Classical Support Vector Machine (SVM) for Iris Dataset
#
# In this notebook, is an implementation of a classical Support Vector Machine (SVM) for the Iris dataset. A powerful and widely used classical machine learning model known for its ability to handle complex decision boundaries, this is used to compare the performances of the classical SVM and quantum circuits.

# %%
from sklearn.datasets import load_iris, load_wine
import pandas as pd
import seaborn as sns
from sklearn.svm import SVC
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import time
from qiskit_machine_learning.algorithms.classifiers import VQC
from IPython.display import clear_output
from sklearn.model_selection import train_test_split
from qiskit.utils import algorithm_globals
plt.style.use('ipynb')

# %% [markdown]
# ### Iris Dataset
#
# Then loading the Iris dataset, preprocessing by applying Min-Max scaling to normalize the feature values.Finally, a pair plot is generated using Seaborn, visually displaying pairwise scatter plots of the features with different colors representing different classes of iris flowers, providing a quick visual overview of the data's distribution and relationships.

# %%
iris_dataset = load_iris()
X = iris_dataset.data
X = MinMaxScaler().fit_transform(X)
Y = iris_dataset.target
df = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
df["class"] = pd.Series(iris_dataset.target)
ss= sns.pairplot(df, hue="class", palette="hls")

# %% [markdown]
# ### Training
#
# Utilizing the popular scikit-learn library, training the SVM to classify the Iris flowers based on their features.

# %%
train_features, test_features, train_labels, test_labels = train_test_split( X, Y, train_size=0.8, random_state=42 )
classifier = SVC()
_ = classifier.fit(train_features, train_labels)

# %% [markdown]
# ### Evaluation
#
# Finally, evaluating the model on the test set.

# %%
predictions = classifier.predict(test_features)

# Calculate the accuracy, F1 score, precision, and recall
accuracy = accuracy_score(test_labels, predictions)* 100
f1 = f1_score(test_labels, predictions, average='macro')* 100
precision = precision_score(test_labels, predictions, average='macro')* 100
recall = recall_score(test_labels, predictions, average='macro')* 100

# Print the results
print("Evaluation Results")
print("_____________________________________________")
print(
            f"\nRecall: {recall:.2f}%"
            f"\nPrecision: {precision:.2f}%"
            f"\nAccuracy: {accuracy:.2f}%"
            f"\nMacro Averaged F1-score: {f1:.2f}%"
            )
print("_____________________________________________")
# Out:
# Evaluation Results
# _____________________________________________
#
# Recall: 100.00%
# Precision: 100.00%
# Accuracy: 100.00%
# Macro Averaged F1-score: 100.00%
# _____________________________________________
